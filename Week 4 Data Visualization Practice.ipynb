# %%
from IPython.display import HTML

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
# %matplotlib inline

# Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14
# Out:
# /Users/trentyu/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
#Creating dummy data for example

# %%
df = pd.DataFrame(np.random.randn(10, 4), 
                  columns=['col1', 'col2', 'col3', 'col4'],
                  index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']) #give names to each row

# %%
df
# Out:
#        col1      col2      col3      col4
# a  1.787004 -0.026947  0.191186  1.106345
# b -0.417371 -0.325151  0.027856 -0.529598
# c  0.082438 -1.067791  0.884526 -0.305077
# d -0.792523  1.659984 -1.304042 -1.311803
# e -0.972091  0.537861 -0.032770  1.226896
# f -0.752882  0.017897 -0.427384  1.006578
# g -0.812491  0.103387 -1.438480  1.300543
# h -1.009689 -1.376569 -1.268259  1.444578
# i  1.208043 -0.416224 -0.232781  0.313983
# j -0.843188  0.436474  1.057876  2.475313

# %%
#Import dataset


data = 'drinks.csv'
drink_cols = ['country', 'beer', 'spirit', 'wine', 'liters', 'continent']
drinks = pd.read_csv(data, header=0, names=drink_cols, na_filter=False)

# %%
drinks
# Out:
#          country  beer  spirit  wine  liters continent
# 0    Afghanistan     0       0     0     0.0        AS
# 1        Albania    89     132    54     4.9        EU
# 2        Algeria    25       0    14     0.7        AF
# 3        Andorra   245     138   312    12.4        EU
# 4         Angola   217      57    45     5.9        AF
# ..           ...   ...     ...   ...     ...       ...
# 188    Venezuela   333     100     3     7.7        SA
# 189      Vietnam   111       2     1     2.0        AS
# 190        Yemen     6       0     0     0.1        AS
# 191       Zambia    32      19     4     2.5        AF
# 192     Zimbabwe    64      18     4     4.7        AF
#
# [193 rows x 6 columns]

# %%
drinks.head()
# Out:
#        country  beer  spirit  wine  liters continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF
# 3      Andorra   245     138   312    12.4        EU
# 4       Angola   217      57    45     5.9        AF

# %%
# Read in the Boston housing data.
housing_csv = 'boston_housing_data.csv'
housing = pd.read_csv(housing_csv)

# %%
housing.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
# Read in the ufo data.
ufo = pd.read_csv('ufo.csv')
ufo['Time'] = pd.to_datetime(ufo.Time)
ufo['Year'] = ufo.Time.dt.year # make another column for Year

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time  Year
# 0 1930-06-01 22:00:00  1930
# 1 1930-06-30 20:00:00  1930
# 2 1931-02-15 14:00:00  1931
# 3 1931-06-01 13:00:00  1931
# 4 1933-04-18 19:00:00  1933

# %%
ufo.Year.value_counts().sort_index()
# Out:
# 1930       2
# 1931       2
# 1933       1
# 1934       1
# 1935       1
#         ...
# 2010    4154
# 2011    5089
# 2012    7263
# 2013    7003
# 2014    5382
# Name: Year, Length: 82, dtype: int64

# %%
#Practice Question
housing[['ZN','INDUS']].plot(figsize=(12,8), style = {'ZN':'g','INDUS':'--b'});

# %%
#Practice Question 2-1
#Create a bar chart using col1 and col2
#Move the legend to the lower-left corner

# %%
ax = df.plot(y=["col1","col2"], kind = 'bar', rot=0)
ax.legend(loc=3)

# %%
#Practice Question 2-1
#Create a bar chart using col1 and col2 with horizon bars
#Move the legend to the upper-right corner

# %%
ax = df.plot(y=["col1","col2"], kind = 'barh', rot=0);

ax.legend(loc=3);

# %%
#Practice 3
#Create a histogram with pandas for using MEDV in the housing data
housing.MEDV.plot(kind="hist",bins = 20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#Practice 5-1
#Create a scatter plot of two heatmap entries that appear to have a very positive correlation.

# %%
housing.plot(kind='scatter', x = 'RM', y = 'MEDV', alpha=0.3);

# %%
#Practice 5-2
#create a scatter plot of two heatmap entries that appear to have negative correlation.


housing.plot(kind='scatter', x='LSTAT', y='MEDV', c='red', alpha=0.3)
# Out:
# <AxesSubplot:xlabel='LSTAT', ylabel='MEDV'>
